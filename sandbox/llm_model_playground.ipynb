# %% [markdown]
# # Generative AI Plot / Choice Generation Demo + Script

# %%
# !pip install together==1.2.0
# !pip install wikipedia-api
# Out:
# Requirement already satisfied: together==1.2.0 in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.3 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (3.11.9)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (8.1.7)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (0.2.0)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (3.16.1)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (1.26.4)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (10.4.0)
# Requirement already satisfied: pyarrow>=10.0.1 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (17.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (2.10.3)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (2.32.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (4.66.6)
# Requirement already satisfied: typer<0.13,>=0.9 in /usr/local/lib/python3.10/dist-packages (from together==1.2.0) (0.12.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together==1.2.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together==1.2.0) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together==1.2.0) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together==1.2.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together==1.2.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together==1.2.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together==1.2.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together==1.2.0) (1.18.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together==1.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together==1.2.0) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together==1.2.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together==1.2.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together==1.2.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together==1.2.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together==1.2.0) (2024.8.30)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13,>=0.9->together==1.2.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13,>=0.9->together==1.2.0) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<0.13,>=0.9->together==1.2.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<0.13,>=0.9->together==1.2.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.13,>=0.9->together==1.2.0) (0.1.2)
# Collecting wikipedia-api
#   Using cached wikipedia_api-0.7.1.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from wikipedia-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2024.8.30)
# Building wheels for collected packages: wikipedia-api
#   Building wheel for wikipedia-api (setup.py) ... done
#   Created wheel for wikipedia-api: filename=Wikipedia_API-0.7.1-py3-none-any.whl size=14346 sha256=37b28097df8b363eee55fe041a1dab71acfa0a6ded0b4a2a610a0d4b19d34d64
#   Stored in directory: /root/.cache/pip/wheels/4c/96/18/b9201cc3e8b47b02b510460210cfd832ccf10c0c4dd0522962
# Successfully built wikipedia-api
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.7.1

# %%
import wikipediaapi
import json

# %% [markdown]
# ## Proof Of Concept

# %%
wiki_wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')


def get_plot(title):
    """
    Retrieves the plot summary of the given title from Wikipedia.
    """
    page = wiki_wiki.page(title)
    if not page.exists():
        print(f"Page '{title}' does not exist.")
        return None

    possible_sections = ['Plot', 'Synopsis', 'Summary', 'Plot summary', 'Story']
    plot_section = None
    for section_title in possible_sections:
        plot_section = page.section_by_title(section_title)
        if plot_section:
            break
    if plot_section:
        return plot_section.text
    else:
        print(f"No plot section found for '{title}'.")
        return None

# %%
IP = 'Dracula'

system_prompt = f"""
Your job is to adapt the story of {IP} and create a branching storyline that incorporates similar elements while introducing new twists and engaging paths for players.
Instructions:
- Only generate in plain text without formatting.
- Use simple, clear language that is easy to understand and avoids being overly descriptive.
- Ensure each branching storyline offers meaningful player choices and consequences.
- Stay concise, limiting each storyline description to 3-5 sentences.
"""

plot_prompt = f"""
Generate a creative, original adaptation of {IP}'s plot, introducing similar themes and elements while creating 4 new, engaging branching storylines for players.

Output content in the form:
Plot Summary: <PLOT SUMMARY>
Branching Storylines: <BRANCHING STORYLINE DESCRIPTIONS>

{IP} Plot Summary: {get_plot(IP)}"""

# %%
plot_prompt
# Out:
# '\nGenerate a creative, original adaptation of Dracula\'s plot, introducing similar themes and elements while creating 4 new, engaging branching storylines for players.\n\nOutput content in the form:\nPlot Summary: <PLOT SUMMARY>\nBranching Storylines: <BRANCHING STORYLINE DESCRIPTIONS>\n\nDracula Plot Summary: Jonathan Harker, a newly qualified English solicitor, visits Count Dracula at his castle in the Carpathian Mountains to help the Count purchase a house near London. Ignoring the Count\'s warning, Harker wanders the castle at night and encounters three vampire women; Dracula rescues Harker, and gives the women a small child bound inside a bag. Harker awakens in bed; soon after, Dracula leaves the castle, abandoning him to the women. Harker escapes and ends up delirious in a Budapest hospital. Dracula takes a ship called the Demeter for England with boxes of earth from his castle. The captain\'s log narrates the crew\'s disappearance until he alone remains, bound to the helm to maintain course. An animal resembling a large dog is seen leaping ashore when the ship runs aground at Whitby.\nLucy Westenra\'s letter to her best friend, Harker\'s fiancée Mina Murray,  describes her marriage proposals from Dr. John Seward, Quincey Morris, and Arthur Holmwood. Lucy accepts Holmwood\'s, but all remain friends. Mina joins Lucy on holiday in Whitby. Lucy begins sleepwalking. After his ship lands there, Dracula stalks Lucy. Mina receives a letter about her missing fiancé\'s illness, and goes to Budapest to nurse him. Lucy becomes very ill. Seward\'s old teacher, Professor Abraham Van Helsing, determines the nature of Lucy\'s condition, but refuses to disclose it. He diagnoses her with acute blood-loss. Van Helsing places garlic flowers around her room and makes her a necklace of them. Lucy\'s mother removes the garlic flowers, not knowing they repel vampires. While Seward and Van Helsing are absent, Lucy and her mother are terrified by a wolf and Mrs. Westenra dies of a heart attack; Lucy dies shortly thereafter. After her burial, newspapers report children being stalked in the night by a "bloofer lady" (beautiful lady), and Van Helsing deduces it is Lucy. The four go to her tomb and see that she is a vampire. They stake her heart, behead her, and fill her mouth with garlic. Jonathan Harker and his now-wife Mina have returned, and they join the campaign against Dracula.\nEveryone stays at Dr. Seward\'s asylum as the men begin to hunt Dracula. Van Helsing finally reveals that vampires can only rest on earth from their homeland. Dracula communicates with Seward\'s patient, Renfield, an insane man who eats vermin to absorb their life force. After Dracula learns of the group\'s plot against him, he uses Renfield to enter the asylum. He secretly attacks Mina three times, drinking her blood each time and forcing Mina to drink his blood on the final visit. She is cursed to become a vampire after her death unless Dracula is killed. As the men find Dracula\'s properties, they discover many earth boxes within. The vampire hunters open each of the boxes and seal wafers of sacramental bread inside them, rendering them useless to Dracula. They attempt to trap the Count in his Piccadilly house, but he escapes. They learn that Dracula is fleeing to his castle in Transylvania with his last box. Mina has a faint psychic connection to Dracula, which Van Helsing exploits via hypnosis to track Dracula\'s movements. Guided by Mina, they pursue him.\nIn Galatz, Romania, the hunters split up. Van Helsing and Mina go to Dracula\'s castle, where the professor destroys the vampire women. Jonathan Harker and Arthur Holmwood follow Dracula\'s boat on the river, while Quincey Morris and John Seward parallel them on land. After Dracula\'s box is finally loaded onto a wagon by Romani men, the hunters converge and attack it. After routing the Romani, Harker decapitates Dracula as Quincey stabs him in the heart. Dracula crumbles to dust, freeing Mina from her vampir ...

# %%
from together import Together

client = Together(api_key='')

output = client.chat.completions.create(
    model="meta-llama/Llama-3-70b-chat-hf",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": plot_prompt}
    ],
)

# %%
plot_output =output.choices[0].message.content
print(plot_output)
# Out:
# Here is a creative, original adaptation of Dracula's plot with 4 new branching storylines for players:
#
# Plot Summary: In the small town of Ravenswood, a mysterious stranger named Count Draconis arrives, seeking to purchase an old mansion on the outskirts of town. Local solicitor, Emily Welles, is tasked with finalizing the sale, but soon discovers that the Count's true intentions are far more sinister. As the town falls under the Count's dark influence, Emily must join forces with a group of allies to uncover the truth behind the Count's powers and stop him before it's too late.
#
# Branching Storylines:
#
# **Path 1: The Mysterious Heir**
# Emily discovers a cryptic letter suggesting that she is the last living heir of an ancient bloodline, making her the only one capable of defeating the Count. As she delves deeper into her family's history, she must choose between embracing her newfound heritage or rejecting it and risking everything. Will she uncover the secrets of her past and claim her birthright, or will she succumb to the Count's manipulation?
#
# **Path 2: The Vampire's Pawn**
# Emily's best friend, Lucy, falls under the Count's spell, becoming a pawn in his game of terror. Emily must navigate the treacherous world of vampire politics to save Lucy, all while confronting the darkness within herself. Will she sacrifice her own morality to rescue her friend, or will she find a way to break the Count's hold on Lucy?
#
# **Path 3: The Professor's Secret**
# Professor Van Helsing, a renowned expert on the supernatural, arrives in Ravenswood, claiming to have a solution to defeat the Count. However, Emily soon discovers that the Professor's motives are not entirely pure. As she uncovers the truth behind his research, she must decide whether to trust him or go rogue. Will she join forces with the Professor, or will she forge her own path to defeat the Count?
#
# **Path 4: The Town's Dark Past**
# As Emily digs deeper into the town's history, she uncovers a dark conspiracy involving the town's founders and the Count. The more she learns, the more she realizes that the town itself is complicit in the Count's evil plans. Will she expose the truth and risk tearing the town apart, or will she keep the secrets buried and hope to find another way to defeat the Count?

# %%
def generate_continuation(context, previous_scenario=None, previous_choice=None, num_choices=4, choices_left=10):
    """
    Generates a continuation of the story based on the given context and an optional choice.
    choices_left details the amount of urgency left, to account for story pacing.
    """
    system_prompt = f"""
    Your job is to tell a continuation of the story based on what previously happened.
    You will be given the overall plot synopsis to help guide the story in that direction.
    The player has {choices_left} choice(s) left.

    Instructions:
    - Use simple, clear language that is easy to understand and avoids being overly descriptive.
    - Stay in third-person point of view.
    - Ensure each branching storyline offers meaningful player choices and consequences.
    - Stay concise, limiting each storyline description to 3-5 sentences.
    - The player has around 10 choices in total. If they have 5-7 left, ramp up the story, aiming for 3-4 choices left as the climax. Begin to aim for an interesting conclusion at 2-1 choices left.
    - All outputs should be in JSON format like so. Do not include anything else:
    {{
      "story_continuation": "[Your story continuation here]",
      "choices": [
        {{
          "choice": 1,
          "action": "[First possible action]"
        }},
        {{
          "choice": 2,
          "action": "[Second possible action]"
        }}
        ...
      ]
    }}
    """

    if previous_choice:
        prompt = f"""
        Write a continuation of the story that progresses the story forward. Include {num_choices} choices for the player to choose from given this generated situation.
        All outputs should be in JSON format. Do not include anything else.

        The following scenario has just occured:
        {previous_scenario}

        The player made the following choice:
        {previous_choice}

        Plot Summary: {context}
        """
    else:
        prompt = f"""
        We are at the start of our adventure. Write a continuation of the story that progresses the story forward. Include {num_choices} choices for the player to choose from given this generated situation.
        All outputs should be in JSON format.

        Plot Summary: {context}
        """
    try:

      output = client.chat.completions.create(
      model="meta-llama/Llama-3-70b-chat-hf",
      messages=[
          {"role": "system", "content": system_prompt},
          {"role": "user", "content": prompt}
      ],
    )
      return output.choices[0].message.content
    except Exception as e:
        print(f"Error during generation: {e}")
        return None

# %%
# Example:
# Generated Plot Summary now becomes context: In the small town of Ravenswood, a mysterious stranger named Count Draconis arrives, seeking to purchase an old mansion on the outskirts of town. Local solicitor, Emily Welles, is tasked with facilitating the sale, but soon discovers that the Count's true intentions are far more sinister. As the town falls under the Count's dark influence, Emily must join forces with a group of allies to uncover the truth behind the Count's powers and stop him before it's too late.
# Each path is added to the context (can also put the path name on screen, which I think is cool and engaging): e.g. Emily discovers that she is the last living heir of the original owner of the mansion, and that the Count's true intention is to claim the estate's dark legacy for himself. Players must navigate the complex web of family secrets and ancient curses to uncover the truth about their own past and the source of the Count's power.

# %%
example_context = "In the small town of Ravenswood, a mysterious stranger named Count Draconis arrives, seeking to purchase an old mansion on the outskirts of town. Local solicitor, Emily Welles, is tasked with facilitating the sale, but soon discovers that the Count's true intentions are far more sinister. As the town falls under the Count's dark influence, Emily must join forces with a group of allies to uncover the truth behind the Count's powers and stop him before it's too late. Emily discovers that she is the last living heir of the original owner of the mansion, and that the Count's true intention is to claim the estate's dark legacy for himself. Players must navigate the complex web of family secrets and ancient curses to uncover the truth about their own past and the source of the Count's power."

output = generate_continuation(example_context, choices_left=10)
output
# Out:
# '{\n  "story_continuation": "Emily stood outside the old mansion, her heart racing as she watched Count Draconis\'s carriage disappear into the night. She couldn\'t shake the feeling that she had just made a terrible mistake. As she turned to leave, she noticed a piece of paper on the ground, blown by the wind. It was a letter, addressed to her, with no indication of who had written it. The words sent a chill down her spine: \'You are the last living heir of Malcolm Welles, the original owner of the mansion. The Count\'s true intention is to claim the estate\'s dark legacy for himself. Meet me at the old windmill on the outskirts of town at midnight if you want to know the truth.\'",\n  "choices": [\n    {\n      "choice": 1,\n      "action": "Go to the windmill at midnight, alone and unprepared"\n    },\n    {\n      "choice": 2,\n      "action": " Ignore the letter and try to forget about the whole thing"\n    },\n    {\n      "choice": 3,\n      "action": "Bring a group of trusted friends to the windmill, ready to face whatever lies ahead"\n    },\n    {\n      "choice": 4,\n      "action": "Confront Count Draconis directly, demanding to know what he\'s really after"\n    }\n  ]\n}'

# %%
parsed_data = json.loads(output)
cleaned_json = json.dumps(parsed_data, indent=4)
print(cleaned_json)
# Out:
# {
#     "story_continuation": "Emily stood outside the old mansion, her heart racing as she watched Count Draconis's carriage disappear into the night. She couldn't shake the feeling that she had just made a terrible mistake. As she turned to leave, she noticed a piece of paper on the ground, blown by the wind. It was a letter, addressed to her, with no indication of who had written it. The words sent a chill down her spine: 'You are the last living heir of Malcolm Welles, the original owner of the mansion. The Count's true intention is to claim the estate's dark legacy for himself. Meet me at the old windmill on the outskirts of town at midnight if you want to know the truth.'",
#     "choices": [
#         {
#             "choice": 1,
#             "action": "Go to the windmill at midnight, alone and unprepared"
#         },
#         {
#             "choice": 2,
#             "action": " Ignore the letter and try to forget about the whole thing"
#         },
#         {
#             "choice": 3,
#             "action": "Bring a group of trusted friends to the windmill, ready to face whatever lies ahead"
#         },
#         {
#             "choice": 4,
#             "action": "Confront Count Draconis directly, demanding to know what he's really after"
#         }
#     ]
# }

# %%
output = generate_continuation(example_context,
                               previous_scenario=parsed_data.get("story_continuation"),
                               previous_choice=parsed_data.get("choices")[0]['action'],
                               choices_left=9)
output
# Out:
# '{\n  "story_continuation": "Emily arrived at the old windmill on the outskirts of town, the creaking of the wooden blades echoing through the darkness. She saw a figure cloaked in shadows, waiting for her. As she approached, the figure stepped forward, revealing a woman with piercing green eyes. \'I\'m Arabella, a member of a secret society that has been watching the Count\'s movements,\' she said. \'We know the truth about your family\'s past and the dark legacy that comes with it. But we must be quick, the Count\'s minions are closing in.\'",\n  "choices": [\n    {\n      "choice": 1,\n      "action": "Ask Arabella about the secret society and what they know about the Count\'s powers"\n    },\n    {\n      "choice": 2,\n      "action": "Demand to know more about Emily\'s family\'s past and the dark legacy"\n    },\n    {\n      "choice": 3,\n      "action": "Refuse to trust Arabella and try to leave"\n    },\n    {\n      "choice": 4,\n      "action": "Ask Arabella if she knows anything about the original owner of the mansion, Malcolm Welles"\n    }\n  ]\n}'

# %%
parsed_data = json.loads(output)
cleaned_json = json.dumps(parsed_data, indent=4)
print(cleaned_json)
# Out:
# {
#     "story_continuation": "Emily arrived at the old windmill on the outskirts of town, the creaking of the wooden blades echoing through the darkness. She saw a figure cloaked in shadows, waiting for her. As she approached, the figure stepped forward, revealing a woman with piercing green eyes. 'I'm Arabella, a member of a secret society that has been watching the Count's movements,' she said. 'We know the truth about your family's past and the dark legacy that comes with it. But we must be quick, the Count's minions are closing in.'",
#     "choices": [
#         {
#             "choice": 1,
#             "action": "Ask Arabella about the secret society and what they know about the Count's powers"
#         },
#         {
#             "choice": 2,
#             "action": "Demand to know more about Emily's family's past and the dark legacy"
#         },
#         {
#             "choice": 3,
#             "action": "Refuse to trust Arabella and try to leave"
#         },
#         {
#             "choice": 4,
#             "action": "Ask Arabella if she knows anything about the original owner of the mansion, Malcolm Welles"
#         }
#     ]
# }

# %% [markdown]
# ## Recursive Script

# %%
all_jsons = {}
GENERATION_THRESHOLD = 8
MAX_RETRIES = 5


def initialize_story(IP, num_choices=4):
    """
    Generates the initial story framework for an interactive narrative based on a specific intellectual property (IP).
    This function adapts the original plot of the IP to create a new branching storyline with similar themes but fresh twists and engaging paths.

    Parameters:
    - `IP` (str): The intellectual property (e.g., movie, book, or game) to base the story on.
    - `num_choices` (int): The number of branching story paths to create. Default is 4.
    """

    system_prompt = f"""
    Your job is to adapt the story of {IP} and create a branching storyline that incorporates similar elements while introducing new twists and engaging paths for players.
    Instructions:
    - Use simple, clear language that is easy to understand and avoids being overly descriptive.
    - Ensure each branching storyline offers meaningful player choices and consequences.
    - Stay concise, limiting each storyline description to 3-5 sentences.
    - All outputs should be in JSON format like so. Do not include anything else:
    {{
      "plot_summary": "[Your initial plot summary here]",
      "branching_storylines": [
        {{
          "path": 1,
          "path_name": "Title of path"
          "story_line": "[Summary of first storyline]"
        }},
        {{
          "path": 2,
          "path_name": "Title of path"
          "story_line": "[Summary of second storyline]"
        }}
        ...
      ]
    }}
    """

    plot_prompt = f"""
    Generate a creative, original adaptation of {IP}'s plot, introducing similar themes and elements while creating 4 new, engaging branching storylines for players.
    All outputs should be in JSON format. Do not include anything else.

    {IP} Plot Summary: {get_plot(IP)}"""

    output = client.chat.completions.create(
        model="meta-llama/Llama-3-70b-chat-hf",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": plot_prompt}
        ],
    )

    return output.choices[0].message.content


def assert_valid_json(json_str):
    """
    Attempts to parse a JSON string with retries upon failure.

    Parameters:
        json_str (str): The JSON string to parse.
        max_retries (int): Maximum number of retry attempts.

    Returns:
        True if valid JSON, False otherwise.
    """
    try:
        parsed_data = json.loads(json_str)
        return True
    except json.JSONDecodeError as e:
        return False


# Recursive Builder:
def populate_JSON(context,
                  previous_scenario, previous_choice,
                  label_idx,
                  num_choices=4, choices_left=10):
    """
    Recursively populates a JSON structure for a branching storyline.

    Parameters:
    - `context` (str): The overall storyline context to guide the creation of new continuations.
    - `previous_scenario` (str): The preceding storyline scenario from which new continuations branch.
    - `previous_choice` (str): The player's previous choice that led to the current scenario.
    - 'label_idx' (str): Label for generated choice, used to id/navigate all_jsons.
    - `num_choices` (int): The number of branching choices to create at each step. Default is 4.
    - `choices_left` (int): The remaining depth of choices before the story concludes.
    """

    if choices_left <= GENERATION_THRESHOLD:
      return

    # Assert generated JSON is validly formatted given MAX_RETRIES
    for attempt in range(1, MAX_RETRIES + 1):
        output = generate_continuation(
            context,
            previous_scenario,
            previous_choice,
            num_choices=num_choices,
            choices_left=choices_left
        )

        if assert_valid_json(output):
          break
        elif attempt == MAX_RETRIES:
          print(f"Failed to parse JSON after {MAX_RETRIES} attempts.")
          return

    parsed_data = json.loads(output)
    all_jsons[label_idx] = parsed_data

    current_scenario = parsed_data.get("story_continuation")
    for id, choice in enumerate(parsed_data.get("choices")):
        current_choice = choice["action"]
        populate_JSON(context,
                      previous_scenario=current_scenario,
                      previous_choice=current_choice,
                      label_idx = label_idx + str(id + 1), # 1-indexed to match choice idxs
                      num_choices=num_choices,
                      choices_left=choices_left-1)


def create_story(IP, num_choices=4, choices_left=10):
    """
    Creates a branching interactive story based on a specific intellectual property (IP), generating storylines recursively.

    Parameters:
    - `IP` (str): The intellectual property (e.g., movie, book, or game) to base the story on.
    - `num_choices` (int): The number of branching choices to create at each stage of the storyline. Default is 4.
    - `choices_left` (int): The total depth of choices before the story concludes.
    """
    # Assert generated JSON is validly formatted given MAX_RETRIES
    for attempt in range(1, MAX_RETRIES + 1):
        story = initialize_story(IP, num_choices)
        if assert_valid_json(story):
          break
        elif attempt == MAX_RETRIES:
          print(f"Failed to parse JSON after {MAX_RETRIES} attempts.")
          return

    story = json.loads(story)
    all_jsons[""] = story

    initial_context = story.get("plot_summary")

    for id, branch in enumerate(story.get("branching_storylines")):
        path_name = branch["path_name"] # TODO: add to final JSON + Unity
        story_line = branch["story_line"]

        # context for each branch is initial context + overall plot of specific branch
        context = initial_context + " " + story_line
        populate_JSON(context,
                      previous_scenario=None,
                      previous_choice=None,
                      label_idx = str(id + 1), # 1-indexed to match choice idxs
                      num_choices=num_choices,
                      choices_left=choices_left)

# %%
create_story('Dracula')

# %%
cleaned_json = json.dumps(all_jsons, indent=4)
print(cleaned_json)
# Out:
# {
#     "": {
#         "plot_summary": "In the modern city of New Haven, a mysterious corporation called 'Eclipse' has taken over the city's infrastructure, and people are disappearing at an alarming rate. The main character, a brilliant journalist named Maya, receives a cryptic message from an anonymous source claiming to have information about Eclipse's true intentions. As Maya delves deeper into the mystery, she discovers that Eclipse is led by a charismatic and enigmatic figure known only as 'The Archon', who seems to have supernatural abilities.",
#         "branching_storylines": [
#             {
#                 "path": 1,
#                 "path_name": "The Whistleblower's Trail",
#                 "story_line": "Maya follows the trail of clues left by the anonymous source, leading her to a hidden underground bunker where she finds evidence of Eclipse's sinister experiments. She must decide whether to go public with the information or continue investigating to uncover more secrets."
#             },
#             {
#                 "path": 2,
#                 "path_name": "The Vampire's Prey",
#                 "story_line": "Maya is attacked by a mysterious figure with supernatural strength and agility. As she recovers from the attack, she begins to experience strange and terrifying symptoms, hinting that she may be turning into a vampire. She must choose between seeking help from a mysterious organization claiming to hunt vampires or trying to find a cure on her own."
#             },
#             {
#                 "path": 3,
#                 "path_name": "The Corporate Conspiracy",
#                 "story_line": "Maya infiltrates Eclipse's headquarters, posing as a new employee, to gather evidence of their wrongdoings. As she rises through the ranks, she discovers that The Archon's true intentions are far more sinister than she initially thought. She must decide whether to continue playing the role or risk everything to expose the truth."
#             },
#             {
#                 "path": 4,
#                 "path_name": "The Ancient Prophecy",
#                 "story_line": "Maya discovers an ancient text that speaks of an ancient evil that has been awakened in New Haven. As she delves deeper into the prophecy, she realizes that The Archon may be the key to unlocking an ancient power that could bring about a new era of darkness. She must choose between stopping The Archon or joining forces with him to fulfill the prophecy."
#             }
#         ]
#     },
#     "1": {
#         "story_continuation": "Maya's heart raced as she explored the hidden bunker, uncovering disturbing evidence of Eclipse's experiments. She found records of human subjects being subjected to strange procedures, and cryptic notes referencing 'The Ascension Project'. Suddenly, she heard footsteps echoing through the corridors, and realized she wasn't alone. Maya knew she had to act fast, or risk being caught by Eclipse's agents.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya quickly gathers as much evidence as she can and makes a run for the exit, hoping to escape undetected."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya decides to investigate the source of the footsteps, trying to gather more information about who or what is coming for her."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya searches the bunker for a way to destroy the evidence, hoping to prevent Eclipse from continuing their sinister experiments."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya tries to find a way to contact the anonymous source, hoping they can provide more guidance and support in her investigation."
#             }
#         ]
#     },
#     "11": {
#         "story_continuation": "Maya sprinted through the corridors, her heart pounding in her chest. She clutched the evidence she had gathered, praying it would be enough to expose Eclipse's sinister activities. As she approached the exit, she heard the footsteps getting closer, and she knew she had to move fast. She burst through the door, finding herself in a dimly lit alleyway. The cool night air hit her like a slap in the face, and she took a deep breath, trying to calm down. But she knew she couldn't stay there for long - Eclipse's agents would be hot on her heels.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya quickly pulls out her phone and dials the number of her trusted source, hoping to get guidance on what to do next."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya looks around the alleyway, trying to get her bearings and figure out where she is in relation to her safe house."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya takes a deep breath and starts to run, trying to put as much distance between herself and the bunker as possible."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya stops for a moment, looking back at the bunker entrance, wondering if she should try to go back and gather more evidence."
#             }
#         ]
#     },
#     "12": {
#         "story_continuation": "Maya crept through the dimly lit corridors, her heart pounding in her chest. She managed to stay ahead of the footsteps, but they were getting closer. She turned a corner and caught a glimpse of a figure in a black jumpsuit, their face obscured by a helmet. Maya recognized the Eclipse insignia on their shoulder. She knew she had to be careful, as they were likely heavily armed and trained. The agent stopped at a door, fiddling with a keycard. Maya realized they were trying to access a restricted area.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya decides to ambush the agent, hoping to take them down quickly and quietly."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya tries to sneak past the agent, hoping to go unnoticed and gain access to the restricted area herself."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya attempts to reason with the agent, trying to find out what they're looking for and if they're willing to defect from Eclipse."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya retreats back into the shadows, deciding to observe the agent from a safe distance and learn more about their mission."
#             }
#         ]
#     },
#     "13": {
#         "story_continuation": "Maya frantically searches the bunker for a way to destroy the evidence, her heart racing with every creak of the old machinery. She finds a control room with a mainframe computer and a series of consoles, but she's not sure which one to use. As she searches, the footsteps grow louder, and she can tell that whoever is coming is getting closer. Maya knows she has to act fast if she wants to prevent Eclipse from continuing their sinister experiments.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya tries to hack into the mainframe computer to delete the files and destroy the evidence remotely."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya searches the consoles for a physical destruction mechanism, such as a self-destruct button or a fire suppression system."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya decides to create a diversion to distract the incoming agents, hoping to buy herself more time to find a way to destroy the evidence."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya prepares to confront the agents head-on, determined to stop them from taking her alive."
#             }
#         ]
#     },
#     "14": {
#         "story_continuation": "Maya quickly searches the bunker for any means of communication, her heart still racing from the sudden appearance of footsteps. She finds a secure phone line and dials the number provided by the anonymous source, hoping they'll answer quickly. As she waits, she hears the footsteps getting closer, and she readies herself to defend herself if necessary. The phone rings several times before a low, gravelly voice answers, 'What have you found, Maya?'",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya quickly briefs the source on her findings, asking for guidance on what to do next."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya demands to know the source's identity and their connection to Eclipse before sharing any information."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya asks the source if they can provide her with a safe extraction from the bunker, fearing for her life."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya decides to keep her findings to herself, suspecting the source might be working with Eclipse."
#             }
#         ]
#     },
#     "2": {
#         "story_continuation": "Maya's world is turned upside down as she struggles to come to terms with the possibility of becoming a vampire. She's plagued by vivid nightmares and an insatiable thirst for blood. Desperate for answers, she reaches out to the mysterious organization that claims to hunt vampires, known only as 'The Order of the Dawn'. They agree to meet with her, but Maya is unsure if she can trust them. As she prepares to meet with The Order, she receives a cryptic message from an unknown number: 'Meet me at the old clock tower at midnight. Come alone.'",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Meet with The Order of the Dawn, hoping they can provide a cure or guidance."
#             },
#             {
#                 "choice": 2,
#                 "action": " Ignore The Order and investigate the clock tower, sensing a potential lead on Eclipse's true intentions."
#             },
#             {
#                 "choice": 3,
#                 "action": "Try to find a way to cure herself on her own, scouring the city for any information on vampire lore and potential antidotes."
#             },
#             {
#                 "choice": 4,
#                 "action": "Confront The Archon directly, determined to get answers about her condition and Eclipse's motives."
#             }
#         ]
#     },
#     "21": {
#         "story_continuation": "Maya arrives at the designated meeting spot, a nondescript office building on the outskirts of New Haven. She's greeted by a stern-looking woman who introduces herself as Agent Rachel Jenkins of The Order of the Dawn. Agent Jenkins listens intently as Maya recounts her experiences, her expression unreadable. When Maya finishes, Agent Jenkins reveals that The Order has been tracking a surge in vampire activity in New Haven, and they believe Eclipse is behind it. She offers Maya a deal: in exchange for her cooperation, The Order will provide her with a serum that can slow down her transformation. But Maya senses there's more to the story, and she's not sure if she can trust Agent Jenkins' motives.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Accept the deal and take the serum, hoping it will buy her time to uncover the truth about Eclipse."
#             },
#             {
#                 "choice": 2,
#                 "action": "Refuse the deal and try to leave, sensing that The Order might be hiding something from her."
#             },
#             {
#                 "choice": 3,
#                 "action": "Ask Agent Jenkins more questions, trying to get to the bottom of The Order's true intentions and their connection to Eclipse."
#             },
#             {
#                 "choice": 4,
#                 "action": "Attack Agent Jenkins, convinced that she's in league with Eclipse and trying to manipulate Maya."
#             }
#         ]
#     },
#     "22": {
#         "story_continuation": "Maya arrives at the old clock tower, her heart racing with anticipation. The wind howls through the abandoned structure, and the creaking of the clock's mechanisms echoes through the night air. As she approaches the entrance, a figure emerges from the shadows. It's a woman with piercing green eyes and raven-black hair, dressed in a long, black coat. She introduces herself as Aria, a rogue member of The Order of the Dawn. Aria claims to have information about Eclipse's true intentions and the source of Maya's newfound... condition.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Trust Aria and ask her what she knows about Eclipse and the vampire curse."
#             },
#             {
#                 "choice": 2,
#                 "action": "Be cautious and ask Aria why she's willing to betray The Order of the Dawn."
#             },
#             {
#                 "choice": 3,
#                 "action": "Attack Aria, sensing a potential trap or threat."
#             },
#             {
#                 "choice": 4,
#                 "action": "Try to leave, feeling uneasy about the situation and Aria's true motives."
#             }
#         ]
#     },
#     "23": {
#         "story_continuation": "Maya's search for a cure leads her to a hidden underground library, where she discovers ancient texts and forbidden knowledge. She learns that the only way to reverse the transformation is to find the 'Elixir of Life', a mythical potion rumored to be hidden in the city's oldest and most abandoned places. As she pours over the texts, she realizes that she's not alone in the library. A figure, shrouded in shadows, watches her from the corner of the room. Maya's instincts scream at her to flee, but her thirst for answers keeps her rooted to the spot.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Confront the mysterious figure and demand to know what they want."
#             },
#             {
#                 "choice": 2,
#                 "action": "Try to sneak past the figure and escape into the night, hoping to find the Elixir of Life on her own."
#             },
#             {
#                 "choice": 3,
#                 "action": "Attempt to reason with the figure, hoping they might possess knowledge about the Elixir or the vampire curse."
#             },
#             {
#                 "choice": 4,
#                 "action": "Use her newfound supernatural abilities to intimidate the figure and assert her dominance."
#             }
#         ]
#     },
#     "24": {
#         "story_continuation": "Maya stands before The Archon, her heart racing with anticipation and fear. The Archon's piercing gaze seems to bore into her soul, and Maya can't help but feel like she's being sized up like prey. 'So, you're the one who's been poking around in my business,' The Archon says, their voice low and menacing. 'I must admit, I'm intrigued. You're not like the others.' The Archon takes a step closer, their eyes flashing with an otherworldly intensity. 'Tell me, Maya, what do you want to know?'",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Demand to know what Eclipse is doing to the people of New Haven and what their true intentions are."
#             },
#             {
#                 "choice": 2,
#                 "action": "Ask The Archon about her condition and what's happening to her body."
#             },
#             {
#                 "choice": 3,
#                 "action": "Try to negotiate with The Archon, offering to keep quiet about Eclipse's activities in exchange for a cure."
#             },
#             {
#                 "choice": 4,
#                 "action": "Attack The Archon, determined to take them down and put an end to Eclipse's sinister plans."
#             }
#         ]
#     },
#     "3": {
#         "story_continuation": "Maya has just started her new job at Eclipse's headquarters, trying to blend in with the other employees. She's been assigned to the marketing department, where she's been tasked with creating promotional materials for Eclipse's latest project, codenamed 'Elysium'. As she works, she can't help but notice the eerie atmosphere in the office, with employees whispering to each other in hushed tones and avoiding eye contact. Maya's supervisor, a stern-looking woman named Ms. Jenkins, seems particularly interested in Maya's work, often stopping by her desk to 'offer guidance'. Maya begins to suspect that Ms. Jenkins might be more than just a supervisor, but a watchdog tasked with keeping an eye on her.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya decides to play it safe and focus on her work, trying to gather more information about Elysium without arousing suspicion."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya tries to strike up a conversation with Ms. Jenkins, hoping to gain her trust and learn more about her true role in the company."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya sneaks away from her desk to explore the office, searching for any clues or hidden documents that might reveal Eclipse's true intentions."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya decides to take a risk and send an anonymous message to her source, hoping to get more information about The Archon's plans and how she can take him down."
#             }
#         ]
#     },
#     "31": {
#         "story_continuation": "As Maya continues to work on the promotional materials for Elysium, she starts to notice that her designs are being heavily scrutinized by Ms. Jenkins. Every minor detail is being picked apart, and Maya begins to feel like she's being micromanaged. She tries to brush it off as mere paranoia, but the constant supervision is starting to take a toll on her nerves. One day, while working late, Maya receives an encrypted message on her company-issued phone. The message reads: 'Meet me in the break room at 5 PM. Come alone.' The message is unsigned, but Maya has a feeling that it might be from someone who can help her uncover the truth about Eclipse.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya decides to ignore the message and continue working on her project, hoping to avoid any unnecessary attention."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya decides to investigate the break room at 5 PM, but she brings a small recorder with her to gather evidence of any potential meeting."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya decides to report the message to Ms. Jenkins, hoping to gain her trust and potentially uncover more information about the mysterious message."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya decides to sneak out of the office early and do some reconnaissance on the break room, trying to gather more information about the mysterious meeting before it happens."
#             }
#         ]
#     },
#     "32": {
#         "story_continuation": "Maya tries to strike up a conversation with Ms. Jenkins, asking her about her weekend and attempting to find common ground. Ms. Jenkins seems hesitant at first, but eventually warms up to Maya's friendly demeanor. As they chat, Maya learns that Ms. Jenkins has been with Eclipse for over a decade and has seen the company grow from a small startup to a global powerhouse. Maya senses that Ms. Jenkins is hiding something, but can't quite put her finger on it. As their conversation comes to a close, Ms. Jenkins mentions that she'll be attending a high-level meeting later that day and invites Maya to join her.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya accepts the invitation, hoping to learn more about the company's inner workings and potentially gather evidence of their wrongdoings."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya declines the invitation, feeling that she's already pushed her luck with Ms. Jenkins and doesn't want to arouse suspicion."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya asks Ms. Jenkins if she can tag along to the meeting, but only to take notes and provide support, trying to appear as non-threatening as possible."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya uses the opportunity to ask Ms. Jenkins more pointed questions about the company's projects and goals, trying to get a better sense of what's really going on at Eclipse."
#             }
#         ]
#     },
#     "33": {
#         "story_continuation": "Maya manages to slip away from her desk without drawing attention to herself and begins to explore the office. She makes her way to the floor's central hub, where she notices a restricted access door with a keycard reader. She wonders what could be behind that door and whether it's related to Elysium. As she observes the area, she notices a few employees gathered near the water cooler, whispering and glancing around nervously. Maya approaches them, trying to act nonchalant, and overhears snippets of their conversation about 'the incident' and 'the package'.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya tries to join the conversation, asking the employees about 'the incident' and 'the package', hoping to gather more information."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya decides to investigate the restricted access door, trying to find a way to bypass the keycard reader or sneak in unnoticed."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya returns to her desk, pretending she was just getting a drink, and tries to focus on her work, hoping to avoid drawing attention to herself."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya approaches Ms. Jenkins, asking for 'guidance' on her project, trying to gauge her supervisor's reaction and see if she's involved in whatever is going on."
#             }
#         ]
#     },
#     "34": {
#         "story_continuation": "Maya sends the anonymous message to her source, her heart racing with anticipation. She tries to focus on her work, but her mind keeps wandering back to the cryptic message she received. Suddenly, her computer beeps, indicating a new email. Maya's heart skips a beat as she sees a response from her source. The message reads: 'Meet me at the old clock tower at midnight. Come alone.' Maya feels a shiver run down her spine as she wonders what her source has planned. She looks around the office, making sure no one is watching her, before quickly deleting the message and trying to compose herself.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya decides to ignore the message and focus on her work, trying to avoid drawing attention to herself."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya can't resist the urge to investigate and decides to sneak out of the office to do some reconnaissance on the clock tower."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya tries to gather more information about the clock tower and its possible connection to Eclipse before deciding what to do."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya decides to take a risk and confide in a coworker she's been friendly with, hoping they might be able to provide some insight or assistance."
#             }
#         ]
#     },
#     "4": {
#         "story_continuation": "Maya sat in her dimly lit apartment, surrounded by stacks of research and notes. She had been investigating Eclipse for weeks, but it wasn't until she received the cryptic message that she began to uncover the true extent of their power. The message had led her to an ancient text, hidden away in a dusty old bookstore. The text spoke of an ancient evil, one that had been awakened in New Haven. Maya's mind raced as she read the words, her journalist instincts screaming that this was the story of a lifetime. But as she delved deeper into the prophecy, she began to realize that The Archon may be the key to unlocking an ancient power that could bring about a new era of darkness. She felt a shiver run down her spine as she wondered if she was in over her head.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya decides to pay a visit to the local expert on the occult, hoping to gain a better understanding of the ancient text and its implications."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya tries to gather more information about The Archon, hoping to uncover his true intentions and motivations."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya reaches out to her contacts in the police department, hoping to get their take on the strange occurrences in New Haven and see if they've noticed anything unusual."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya decides to take a risk and try to infiltrate Eclipse, hoping to get a closer look at their operations and gather evidence of their wrongdoing."
#             }
#         ]
#     },
#     "41": {
#         "story_continuation": "Maya arrived at the local expert's shop, a small, cluttered store filled with strange artifacts and dusty tomes. The expert, an old man named Professor Thaddeus, greeted her warmly and listened intently as she recounted her discovery. His eyes widened as she showed him the ancient text, and he nodded gravely. 'Yes, I know of this prophecy,' he said. 'It speaks of a great and terrible power, one that could bring about a new era of darkness. But it also speaks of a way to stop it, a ritual that requires great courage and sacrifice.'",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya asks Professor Thaddeus to explain the ritual and how it can be performed."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya asks Professor Thaddeus if he knows anything about The Archon's true intentions and motivations."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya asks Professor Thaddeus if he knows of anyone who might be able to help her stop The Archon and prevent the prophecy from being fulfilled."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya decides to leave and do some more research on her own, feeling that Professor Thaddeus might be hiding something from her."
#             }
#         ]
#     },
#     "42": {
#         "story_continuation": "Maya's research led her to a hidden underground forum, where she stumbled upon a cryptic conversation between two individuals who claimed to have had encounters with The Archon. They spoke of his mesmerizing presence and his ability to manipulate people's minds. One of the individuals, who went by the username 'Raven', mentioned a secret meeting with The Archon at an abandoned warehouse on the outskirts of New Haven. Maya's heart raced as she realized this could be her chance to finally meet The Archon and uncover his true intentions.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya decides to attend the secret meeting, hoping to blend in and gather more information about The Archon's plans."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya tries to track down 'Raven', hoping to learn more about their encounter with The Archon and gain insight into his motivations."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya decides to investigate the abandoned warehouse, searching for any clues or evidence that could lead her to The Archon."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya reaches out to her contacts in the city, hoping to gather a team of allies to help her take down The Archon and Eclipse."
#             }
#         ]
#     },
#     "43": {
#         "story_continuation": "Maya's contacts in the police department were hesitant to share any information, but one officer, a trusted source named Detective James, agreed to meet with her in person. Over coffee, James revealed that there had been a surge in reports of strange occurrences and unexplained events, but the department was under pressure from Eclipse to keep the lid on. He warned Maya to be careful, as Eclipse had eyes and ears everywhere. As they parted ways, Maya couldn't shake the feeling that she was being watched. She noticed a black sedan following her as she walked back to her apartment, and her instincts screamed that she needed to take action.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya tries to lose the tail by taking a detour through the city streets."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya confronts the occupants of the black sedan, demanding to know who they are and what they want."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya returns to her apartment and begins to gather her research, preparing to go underground and continue her investigation in secret."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya decides to pay a visit to Eclipse's headquarters, hoping to catch a glimpse of The Archon and get a sense of their operation."
#             }
#         ]
#     },
#     "44": {
#         "story_continuation": "Maya spent hours perfecting her disguise, transforming herself into a young professional eager to join the ranks of Eclipse. She arrived at the corporation's sleek, modern headquarters, her heart racing with anticipation. As she entered the building, she was greeted by a receptionist who barely looked up from her screen. 'Can I help you?' she asked, her tone devoid of warmth. Maya flashed a bright smile, trying to appear confident. 'I'm here for the job interview. I'm excited to learn more about the opportunities at Eclipse.' The receptionist nodded, handing Maya a badge with her fake name on it. 'Take the elevator to the 23rd floor. You'll be meeting with our HR representative.' Maya's palms were sweating as she made her way to the elevator, wondering what she would find on the 23rd floor.",
#         "choices": [
#             {
#                 "choice": 1,
#                 "action": "Maya takes the elevator to the 23rd floor, trying to blend in with the other employees."
#             },
#             {
#                 "choice": 2,
#                 "action": "Maya decides to snoop around the lobby, looking for any clues or information that might give her an edge."
#             },
#             {
#                 "choice": 3,
#                 "action": "Maya tries to strike up a conversation with the receptionist, hoping to gather more information about the company."
#             },
#             {
#                 "choice": 4,
#                 "action": "Maya slips away, deciding to explore the building's lower levels, searching for any hidden secrets or restricted areas."
#             }
#         ]
#     }
# }

# %%
with open("example_data.json", "w") as f:
    json.dump(all_jsons, f)
